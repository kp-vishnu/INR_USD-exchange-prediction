# %%
import pandas as pd
import datetime
from datetime import timedelta, date

# %%
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
start_date = date(2021, 1, 1)
end_date = datetime.date.today()

df = pd.DataFrame()
for single_date in daterange(start_date, end_date):
    dfs = pd.read_html(f'https://www.xe.com/currencytables/?from=INR&date={single_date.strftime("%Y-%m-%d")}')[0]
    dfs['Date'] = single_date.strftime("%Y-%m-%d")
    df = df.append(dfs)
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_61776/233835880.py in <module>
#       4 df = pd.DataFrame()
#       5 for single_date in daterange(start_date, end_date):
# ----> 6     dfs = pd.read_html(f'https://www.xe.com/currencytables/?from=INR&date={single_date.strftime("%Y-%m-%d")}')[0]
#       7     dfs['Date'] = single_date.strftime("%Y-%m-%d")
#       8     df = df.append(dfs)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     904
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#     908             # if `io` is an io-like object, check if it's seekable
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in parse_tables(self)
#     220         list of parsed (header, body, footer) tuples from tables.
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     224
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _build_doc(self)
#     743                     pass
#     744             else:
# --> 745                 raise e
#     746         else:
#     747             if not hasattr(r, "text_content"):
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _build_doc(self)
#     725             if is_url(self.io):
#     726                 with urlopen(self.io) as f:
# --> 727                     r = parse(f, parser=parser)
#     728             else:
#     729                 # try to parse the input in the simplest way
#
# ~\Anaconda3\lib\site-packages\lxml\html\__init__.py in parse(filename_or_url, parser, base_url, **kw)
#     937     if parser is None:
#     938         parser = html_parser
# --> 939     return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#     940
#     941
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseFilelikeDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/parser.pxi in lxml.etree._FileReaderContext.copyToBuffer()
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     460             # Amount is given, implement using readinto
#     461             b = bytearray(amt)
# --> 462             n = self.readinto(b)
#     463             return memoryview(b)[:n].tobytes()
#     464         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     504         # connection, and the user is reading more bytes than will be provided
#     505         # (for example, reading in 1k chunks)
# --> 506         n = self.fp.readinto(b)
#     507         if not n and b:
#     508             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine

# %%
df.to_csv('inr_data_2022.csv')
df = pd.read_csv('inr_data_2022.csv')
df
# Out:
#        Unnamed: 0  Unnamed: 0.1 Currency               Name  Units per INR  \
# 0               0             0      USD          US Dollar   1.342162e-02
# 1               1             1      EUR               Euro   1.180533e-02
# 2               2             2      GBP      British Pound   9.921295e-03
# 3               3             3      INR       Indian Rupee   1.000000e+00
# 4               4             4      AUD  Australian Dollar   1.847720e-02
# ...           ...           ...      ...                ...            ...
# 55338       55338           181      VED                VED   1.023524e-01
# 55339       55339           182      XBT                XBT   5.849879e-07
# 55340       55340           183      XLM      Stellar Lumen   1.075630e-01
# 55341       55341           184      XRP             Ripple   2.603719e-02
# 55342       55342           185      ZWL                ZWL   7.657914e+00
#
#        INR per unit        Date
# 0      7.450667e+01  2022-01-01
# 1      8.470748e+01  2022-01-01
# 2      1.007933e+02  2022-01-01
# 3      1.000000e+00  2022-01-01
# 4      5.412075e+01  2022-01-01
# ...             ...         ...
# 55338  9.770163e+00  2022-10-26
# 55339  1.709437e+06  2022-10-26
# 55340  9.296875e+00  2022-10-26
# 55341  3.840660e+01  2022-10-26
# 55342  1.305839e-01  2022-10-26
#
# [55343 rows x 7 columns]
